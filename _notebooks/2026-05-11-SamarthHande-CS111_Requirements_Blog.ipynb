# %%
---
layout: post 
title: Castle Game
description: Explore the castle and free the prisoner. 
permalink: /blogs/cs111
codemirror: true
toc: false
author: Samarth Hande
---

# %%
# %%js
#
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true,  width: 100%, height: 500px
#
# import GameControl from '@assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelOutside from '@assets/js/projects/castle-game/levels/GameLevelOutside.js';
# import GameLevelArchery from '@assets/js/projects/castle-game/levels/GameLevelArchery.js';
# import GameLevelMaze from '@assets/js/projects/castle-game/levels/GameLevelMaze.js';
# import GameLevelFortress from '@assets/js/projects/castle-game/levels/GameLevelFortress.js';
#
#
# export const gameLevelClasses = [GameLevelOutside, GameLevelArchery, GameLevelMaze, GameLevelFortress];
# export { GameControl };

# %% [markdown]
# ### CS111 Requirements
#
#
# | Section Name | Description | Evidence of Implementation |
# | ------------ | ----------- | ----------- |
# | **Object Oriented Programming (OOP)** |
# | Writing Classes | Creating class definitions to encapsulate data and behavior | |
# | Methods & Parameters | Defining functions within classes that accept input parameters | |
# | Instantiation & Objects | Creating instances of classes and working with object instances | |
# | Inheritance (Basic) | Creating subclasses that inherit properties and methods from parent classes | |
# | Method Overriding | Redefining methods in subclasses to provide specific implementations | |
# | Constructor Chaining | Calling parent class constructors from child class constructors | |
#
# | **Control Structures** |
# | Iteration    | Iterating through a list using loops | [Iteration](https://samarthhande.github.io/portfolio-old/javascript/iteration/inventors-hw) |
# | Conditionals | Using if, else if, else statements | [Conditionals](https://samarthhande.github.io/portfolio-old/javascript/constellators/conditionals-hw) |
# | Nested Conditions | Using nested if-else statements | [Nested Conditions](https://samarthhande.github.io/portfolio-old/javascript/constellators/conditionals-hw) |
#
# | **Data Types** |
# | Numbers     | Number can be used for positions, indexes, etc. | [Numbers](https://samarthhande.github.io/portfolio-old/javascript/homework/math-expressions) |
# | Strings     | Strings can be used for dialogue and paths | [Strings](https://samarthhande.github.io/portfolio-old/javascript/strings/makers-hw) |
# | Booleans    | Booleans can be used for conditions | [Booleans](https://samarthhande.github.io/portfolio-old/javascript/booleans/hmwk) |
# | Arrays      | Arrays can be used for lists | [Arrays](https://samarthhande.github.io/portfolio-old/javascript/array/homework) |
# | Objects (JSON) | Objects can be used for data structures | [Objects (JSON)](https://samarthhande.github.io/portfolio-old/javascript/array/homework) |
#
# | **Operators** |
# | Mathematical | Mathematical operators can be used for calculations | [Mathematical](https://samarthhande.github.io/portfolio-old/javascript/homework/math-expressions) |
# | String Operations | String operators can be used for string manipulation | [String Operations](https://samarthhande.github.io/portfolio-old/javascript/strings/makers-hw) |
# | Boolean Expressions | Boolean expressions can be used for conditions | [Boolean Expressions](https://samarthhande.github.io/portfolio-old/javascript/booleans/hmwk) |
#
# | **Input/Output (IO)** |
# | Keyboard Input | Capturing user input from the keyboard | |
# | Canvas Rendering | Drawing graphics and animations on a canvas element | |
# | GameEnv Configuration | Setting up game environment with configuration options | |
# | API Integration | Integrating external APIs for data or functionality | |
# | Asynchronous I/O | Handling asynchronous operations like API calls or timers | |
# | JSON Parsing | Parsing JSON data for configuration or data exchange | |
#
# | **Documentation** |
# | Code Comments | Adding comments to explain classes and methods | |
# | Mini-Lesson Documentation | Create comic/visual post with embedded runtime game demo | |
# | Code Highlights | Annotate key code snippets in documentation (OOP, APIs, collision) | |
#
# | **Debugging** |
# | Console Debugging | Using console.log() and other debugging techniques to identify and fix issues | |
# | Hit Box Visualization | Using visual debugging to understand collision detection | |
# | Source-Level Debugging | Using browser developer tools to step through code and inspect variables | |
# | Network Debugging | Using browser developer tools to inspect network requests and responses | |
# | Application Debugging | Using browser developer tools to inspect application state and behavior | |
# | Element Inspection | Using browser developer tools to inspect HTML elements and their properties | |
#
# | **Testing & Verification** |
# | Gameplay Testing | Testing game mechanics, controls, and overall user experience | |
# | Integration Testing | Testing the interaction between different components of the game | |
# | API Error Handling | Handling errors when integrating external APIs | |
#
# Each Programming Concept Demonstrated is shown below.
