# %%
---
layout: opencs
toc: True
codemirror: true
title: Samarth Hande CS111 Requirements
description: This is Samarth Hande's blog reflecting on learning with CS111 requirements.
permalink: /blogs/cs111
author: Samarth H
---

# %% [markdown]
# ### CS111 Requirements
#
#
# | Section Name | Description | Homework Link |
# | ------------ | ----------- | ----------- |
# | [Iteration](#iteration)    | Iterating through a list using loops | [Iteration](https://samarthhande.github.io/portfolio-old/javascript/iteration/inventors-hw) |
# | [Conditionals](#conditionals) | Using if, else if, else statements | [Conditionals](https://samarthhande.github.io/portfolio-old/javascript/constellators/conditionals-hw) |
# | [Nested Conditions](#nested-conditions) | Using nested if-else statements | [Nested Conditions](https://samarthhande.github.io/portfolio-old/javascript/constellators/conditionals-hw) |
# | **Data Types** |
# | [Numbers](#numbers)     | Number can be used for positions, indexes, etc. | [Numbers](https://samarthhande.github.io/portfolio-old/javascript/homework/math-expressions) |
# | [Strings](#strings)     | Strings can be used for dialogue and paths | [Strings](https://samarthhande.github.io/portfolio-old/javascript/strings/makers-hw) |
# | [Booleans](#booleans)    | Booleans can be used for conditions | [Booleans](https://samarthhande.github.io/portfolio-old/javascript/booleans/hmwk) |
# | [Arrays](#arrays)      | Arrays can be used for lists | [Arrays](https://samarthhande.github.io/portfolio-old/javascript/array/homework) |
# | [Objects (JSON)](#objects-json) | Objects can be used for data structures | [Objects (JSON)](https://samarthhande.github.io/portfolio-old/javascript/array/homework) |
# | **Operators** |
# | [Mathematical](#mathematical) | Mathematical operators can be used for calculations | [Mathematical](https://samarthhande.github.io/portfolio-old/javascript/homework/math-expressions) |
# | [String Operations](#string-operations) | String operators can be used for string manipulation | [String Operations](https://samarthhande.github.io/portfolio-old/javascript/strings/makers-hw) |
# | [Boolean Expressions](#boolean-expressions) | Boolean expressions can be used for conditions | [Boolean Expressions](https://samarthhande.github.io/portfolio-old/javascript/booleans/hmwk) |
#
#
# Each Programming Concept Demonstrated is shown below.
